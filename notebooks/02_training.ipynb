# %% [markdown]
# # 🚀 NVIDIA Nemotron Tuning — Phase 2: QLoRA SFT and GRPO Training
#
# This notebook triggers **Phase 2 (Model Training and Fine-Tuning)** of the Nemotron pipeline.
#
# ## Training Flow:
# 1. **Environment Setup**: Standardizes installations and configures NF4 double quantization parameters.
# 2. **Stage A (SFT)**: Fine-tunes target attention and MLP projection weights on Phase 1 CoT templates to lock in structure compliance.
# 3. **Stage B (GRPO)**: Applies Group Relative Policy Optimization reinforcement learning to reward accuracy and format correctness.
# 4. **Packaging**: Saves LoRA adapters under `models/lora_adapter` ready for packaging.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src import config
from src.train import run_training_pipeline

print(f"Detected hardware profile:   {config.PROFILE.upper()}")
print(f"Base Model:                 {config.MODEL_ID}")
print(f"QLoRA Constraints:          Rank={config.LORA_R}, Alpha={config.LORA_ALPHA}")

# %%
# Execute the SFT + GRPO training runner
# Set limit=True for a quick multi-step validation check
run_training_pipeline(limit=False)
