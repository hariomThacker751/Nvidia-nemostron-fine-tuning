# %% [markdown]
# # 🏆 NVIDIA Nemotron — Phase 3: Category-Aware Adaptive Consistency Inference
#
# This notebook coordinates **Phase 3 (Submissions and Advanced Inference Strategy)** of the Nemotron pipeline.
#
# ## Key Inference Strategies:
# 1. **Category Routing**: Diverts input prompts to specialized category system cards.
# 2. **Adaptive Voting (SC@N)**: Configures voting size dynamically. Harder puzzle domains get higher compute allocation.
# 3. **Retry Uncertainty**: Automatically schedules higher vote samples and high-temperature exploration for uncertain or disagreed predictions.
# 4. **LaTeX Normalization**: Resolves equivalent decimal values, LaTeX fraction mappings, and scientific symbols to yield clean exact-match submissions.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src import config
from src.inference import run_inference_pipeline

print(f"Inference parameters:      Temp={config.INFERENCE_TEMP}, Default Votes={config.N_VOTES_DEFAULT}")
print(f"Retry triggers:             Retry threshold={config.LOW_CONF_THRESHOLD}, Retry Votes={config.RETRY_N_VOTES}")

# %%
# Execute inference strategy on raw test records
# Set limit=2 to run a quick test check
run_inference_pipeline(limit=None)
